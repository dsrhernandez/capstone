# %%
import pandas as pd
ddf = pd.read_csv('diabetic_data.csv', low_memory= False)
ddf 
#loading df into juypter
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
ddf.shape 
#data exploration
# Out:
# (101766, 50)

# %%
ddf.count()
#data exploration
# Out:
# encounter_id                101766
# patient_nbr                 101766
# race                        101766
# gender                      101766
# age                         101766
# weight                      101766
# admission_type_id           101766
# discharge_disposition_id    101766
# admission_source_id         101766
# time_in_hospital            101766
# payer_code                  101766
# medical_specialty           101766
# num_lab_procedures          101766
# num_procedures              101766
# num_medications             101766
# number_outpatient           101766
# number_emergency            101766
# number_inpatient            101766
# diag_1                      101766
# diag_2                      101766
# diag_3                      101766
# number_diagnoses            101766
# max_glu_serum               101766
# A1Cresult                   101766
# metformin                   101766
# repaglinide                 101766
# nateglinide                 101766
# ...

# %%
summary_statistics = ddf.describe()
summary_statistics
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
ddf.groupby('readmitted')['age'].value_counts() 
#data exploration 
#grouping values according to readmitted and age
# Out:
# readmitted  age
# <30         [70-80)      3069
#             [60-70)      2502
#             [80-90)      2078
#             [50-60)      1668
#             [40-50)      1027
#             [30-40)       424
#             [90-100)      310
#             [20-30)       236
#             [10-20)        40
#             [0-10)          3
# >30         [70-80)      9475
#             [60-70)      7897
#             [80-90)      6223
#             [50-60)      5917
#             [40-50)      3278
#             [30-40)      1187
#             [90-100)      808
#             [20-30)       510
#             [10-20)       224
#             [0-10)         26
# NO          [70-80)     13524
#             [60-70)     12084
#             [50-60)      9671
#             [80-90)      8896
#             [40-50)      5380
#             [30-40)      2164
#             [90-100)     1675
#             [20-30)       911
#             [10-20)       427
#             [0-10)        132
# ...

# %%
correlation_matrix = ddf.corr()
correlation_matrix 
#correlation analysis
# Out:
# /var/folders/nx/vd7gz3y14h34dwp6_27p8pbh0000gn/T/ipykernel_45755/3852651255.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = ddf.corr()
#                           encounter_id  patient_nbr  admission_type_id  \
# encounter_id                  1.000000     0.512028          -0.158961
# patient_nbr                   0.512028     1.000000          -0.011128
# admission_type_id            -0.158961    -0.011128           1.000000
# discharge_disposition_id     -0.132876    -0.136814           0.083483
# admission_source_id          -0.112402    -0.032568           0.106654
# time_in_hospital             -0.062221    -0.024092          -0.012500
# num_lab_procedures           -0.026062     0.015946          -0.143713
# num_procedures               -0.014225    -0.015570           0.129888
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.histplot(data=ddf, x='time_in_hospital')
plt.title('Time in Hospital Distribution')
plt.xlabel('Days')
plt.ylabel('Count')
plt.show()
#histogram for number of days recorded in the hospital

# %%
readmission_distribution = ddf['readmitted'].value_counts()
readmission_distribution.plot(kind='bar', color=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('DISTRIBUTION OF READMISSION STATUS ')
plt.xlabel('READMISSION STATUS')
plt.ylabel('COUNT')
plt.show() 
#data exploration 
# barchart of readmission distribution

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=ddf, x='race')
plt.title('DISTRIBUTION OF RACES')
plt.xlabel('RACE')
plt.ylabel('COUNT')
plt.xticks(rotation=45)
plt.show()
#data exploration 
#distribution of races

# %%
readmission_by_age = ddf.groupby(['age', 'readmitted']).size().unstack()
readmission_by_age.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('READMISSION COUNTS ACROSS AGE GROUPS')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Readmission Status')
plt.show() 
#readmission of ages

# %%
readmission_by_race = ddf.groupby(['race', 'readmitted']).size().unstack()
readmission_by_race.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('READMISSION COUNTS ACROSS RACES')
plt.xlabel('Race')
plt.ylabel('Count')
plt.legend(title='Readmission Status')
plt.show() 

#readmission of races

# %%
medication_cols = ['metformin', 'insulin', 'glipizide']
for med in medication_cols: 
    sns.countplot(x=med, data=ddf)
    plt.title(f'Distribution of {med} Usage')
    plt.show 
#data exploration
#medication usage exploration

# %%
grouped_data = ddf.groupby('admission_type_id')['time_in_hospital'].mean()
grouped_data.plot(kind='bar', color='darkgreen')
plt.title('Average Time in Hospital by Admission Type')
plt.xlabel('Admission Type')
plt.ylabel('Average Time in Hospital')
plt.show() 
#average time in hospital by admission type using a bar chart

# %%
ddf.isnull().sum()
#data manipulation 
#no column has missing data
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# ...

# %%
df_encoded = pd.get_dummies(ddf, columns=['race', 'gender'], drop_first=True)
df_encoded 
#one-hot encoding on categorical columns race and gender
# Out:
#         encounter_id  patient_nbr      age weight  admission_type_id  \
# 0            2278392      8222157   [0-10)      ?                  6
# 1             149190     55629189  [10-20)      ?                  1
# 2              64410     86047875  [20-30)      ?                  1
# 3             500364     82442376  [30-40)      ?                  1
# 4              16680     42519267  [40-50)      ?                  1
# ...              ...          ...      ...    ...                ...
# 101761     443847548    100162476  [70-80)      ?                  1
# 101762     443847782     74694222  [80-90)      ?                  1
# 101763     443854148     41088789  [70-80)      ?                  1
# 101764     443857166     31693671  [80-90)      ?                  2
# 101765     443867222    175429310  [70-80)      ?                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
age_mapping = {'[0-10)': 0, '[10-20)': 1, '[20-30)':2, '[30-40)': 3, '[40-50)': 4, '[50-60)': 5, '[60-70)':6, '[70-80)':7, '[80-90)':8,'[90-100)':9}
df_encoded['age']=df_encoded['age'].map(age_mapping)
#mapping age groups to respective numerical values

# %%
age_mapping
# Out:
# {'[0-10)': 0,
#  '[10-20)': 1,
#  '[20-30)': 2,
#  '[30-40)': 3,
#  '[40-50)': 4,
#  '[50-60)': 5,
#  '[60-70)': 6,
#  '[70-80)': 7,
#  '[80-90)': 8,
#  '[90-100)': 9}

# %%
df_encoded
# Out:
#         encounter_id  patient_nbr  age weight  admission_type_id  \
# 0            2278392      8222157    0      ?                  6
# 1             149190     55629189    1      ?                  1
# 2              64410     86047875    2      ?                  1
# 3             500364     82442376    3      ?                  1
# 4              16680     42519267    4      ?                  1
# ...              ...          ...  ...    ...                ...
# 101761     443847548    100162476    7      ?                  1
# 101762     443847782     74694222    8      ?                  1
# 101763     443854148     41088789    7      ?                  1
# 101764     443857166     31693671    8      ?                  2
# 101765     443867222    175429310    7      ?                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                             25                    1                 1
# ...

# %%
columns_to_drop = ['weight'] 
ddf_cleaned = ddf.drop(columns=columns_to_drop)
ddf_cleaned 
#dropping weight column because of unknown data entry (?)
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

X_numeric = ddf[['num_lab_procedures', 'num_procedures', 'num_medications']]
y_numeric = ddf['time_in_hospital']

X_train_numeric, X_test_numeric, y_train_numeric, y_test_numeric = train_test_split(X_numeric, y_numeric, test_size=0.2, random_state=42)

linear_model = LinearRegression()
linear_model.fit(X_train_numeric, y_train_numeric)

y_pred_numeric = linear_model.predict(X_test_numeric)

mse = mean_squared_error(y_test_numeric, y_pred_numeric)
r2 = r2_score(y_test_numeric, y_pred_numeric)

plt.scatter(y_test_numeric, y_pred_numeric)
plt.xlabel("Actual Time in Hospital")
plt.ylabel("Predicted Time in Hospital")
plt.title("Linear Regression: Actual vs Predicted Time in Hospital")
plt.show()

print("Linear Regression Model:")
print("Mean Squared Error:", mse)
print("R-squared:", r2)
#implementing features and target variable, train-test split, bulding a linear regression model, making predictions and evaluating the model
#visualizing the predictions vs actual values with a scatter plot
#displaying the evaluaion metrics
# Out:
# Linear Regression Model:
# Mean Squared Error: 6.447867330149717
# R-squared: 0.25921285752766565

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

X_classification = ddf[['num_lab_procedures', 'num_procedures', 'num_medications']]
y_classification = ddf['readmitted']

X_train_classification, X_test_classification, y_train_classification, y_test_classification = train_test_split(X_classification, y_classification, test_size=0.2, random_state=42)

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_classification, y_train_classification)

y_pred_classification = rf_classifier.predict(X_test_classification)

accuracy = accuracy_score(y_test_classification, y_pred_classification)

print("Random Forest Classifier Model:")
print("Accuracy:", accuracy)
print("\nClassification Report:\n", classification_report(y_test_classification, y_pred_classification))
print("\nConfusion Matrix:\n", confusion_matrix(y_test_classification, y_pred_classification))
#implementing features an dtarget variable
#running a train-test split 
#building a random forest classifier model 
#making predictions and evaluating the model 
#displaying the classification report and confusion matrix
# Out:
# Random Forest Classifier Model:
# Accuracy: 0.494890439225705
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          <30       0.12      0.03      0.05      2285
#          >30       0.38      0.27      0.32      7117
#           NO       0.55      0.74      0.63     10952
#
#     accuracy                           0.49     20354
#    macro avg       0.35      0.35      0.33     20354
# weighted avg       0.44      0.49      0.46     20354
#
#
# Confusion Matrix:
#  [[  67  607 1611]
#  [ 210 1956 4951]
#  [ 303 2599 8050]]
